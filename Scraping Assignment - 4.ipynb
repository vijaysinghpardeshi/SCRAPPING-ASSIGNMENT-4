# %% [markdown]
# # Web Scraping Assignment - 4

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")

# %%
# Getting the webpage of mentioned url 
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
#creating empty list
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
#Scraping data of rank details
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[1]')[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')
        

#Scraping data of video names
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[2]')[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

#Scraping data of artist name
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[3]')[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')
    
#Scraping data of upload dates
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[5]')[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')
    
    
#Scraping data of views
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[4]')[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
#DATA FRAMEING
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Artist, Uploaded Date, Views]
# Index: []

# %%
driver.close()

# %% [markdown]
# 2.Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1 st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")

# %%
# Getting the webpage of mentioned url 
driver.get("https://www.bcci.tv/")

# %%
#going to international fixtures page
International = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a') 
International.click()

# %%
#Creating Empty List
Name=[]
Series=[]
Place=[]
Date=[]
Time=[]

#Scrapping Name
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]'):
        Name.append(i.text.replace('-',""))
except NoSuchElementException:
    Name.append('-')

#Scrapping Series
try:
    
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding"]'):
        Series.append(i.text)
except NoSuchElementException:
    Series.append('-')
    
#scrapping Place
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]'):
        Place.append(i.text)
except NoSuchElementException:
    Place.append('-')
    
#Scrapping Date
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]'):
        Date.append(i.text)
except NoSuchElementException:
    Date.append('-')
    
#Scrapping Time
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]'):
        Time.append(i.text.replace('IST',""))
except NoSuchElementException:
    Time.append('-')

    
# Creating Dataframe

Int_Fixtures=pd.DataFrame({})

Int_Fixtures['Match Title']=Name
Int_Fixtures['Series']=Series
Int_Fixtures['Place']=Place
Int_Fixtures['Date']=Date
Int_Fixtures['Time']=Time
Int_Fixtures
# Out:
#   Match Title                       Series                      Place  \
# 0   3rd T20I   ICC MENS T20 WORLD CUP 2022             Perth Stadium,
# 1   4th T20I   ICC MENS T20 WORLD CUP 2022             Adelaide Oval,
# 2   5th T20I   ICC MENS T20 WORLD CUP 2022  Melbourne Cricket Ground,
#
#           Date      Time
# 0  30 OCT 2022  4:30 PM
# 1   2 NOV 2022  1:30 PM
# 2   6 NOV 2022  1:30 PM

# %%
driver.close()

# %% [markdown]
# # 3.Scrape the details of selenium exception from guru99.com.\
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")
driver.maximize_window()

# %%
# Getting the webpage of mentioned url 
driver.get("https://www.guru99.com/")
driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a').click()

driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a/strong').click()
time.sleep(5)

# %%
Name=[]
Description=[]

guru99=driver.find_elements(By.XPATH,'//p//strong')
for i in guru99:
    Name.append(i.text)


    guru99=driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]//p')
for i in guru99:
    Description.append(i.text)

Name=[]
Description=[]

guru99=driver.find_elements(By.XPATH,'//p//strong')
for i in guru99:
    Name.append(i.text)


guru99=driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]//p')
for i in guru99:
    Description.append(i.text)


Desc=[]
for i in range(2,43):
    Desc.append(Description[i].split(':')[1])


Data={'Name':Name[1:42],'Description':Desc}

df=pd.DataFrame(Data)

df
# Out:
#                                         Name  \
# 0             1. ElementNotVisibleException:
# 1          2. ElementNotSelectableException:
# 2                 3. NoSuchElementException:
# 3                   4. NoSuchFrameException:
# 4                5. NoAlertPresentException:
# 5                  6. NoSuchWindowException:
# 6         7. StaleElementReferenceException:
# 7               8. SessionNotFoundException:
# 8                       9. TimeoutException:
# 9                    10. WebDriverException:
# 10            11. ConnectionClosedException:
# 11     12. ElementClickInterceptedException:
# 12      13. ElementNotInteractableException:
# 13             14. ErrorInResponseException:
# 14  15. ErrorHandler.UnknownServerException:
# 15         16. ImeActivationFailedException:
# 16             17. ImeNotAvailableException:
# 17         18. InsecureCertificateException:
# 18             19. InvalidArgumentException:
# 19         20. InvalidCookieDomainException:
# ...

# %%
driver.close()

# %% [markdown]
# Q4) Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(19-20)
#
# D) GSDP(18-19)
#
# E) Share(18-19)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")
driver.maximize_window()

# %%
# Getting the webpage of mentioned url 
driver.get(" http://statisticstimes.com/")

# %%
# India's GDP
india=driver.find_element(By.XPATH,"//div[@class='navbar']/div[2]/div/a[3]").get_attribute("href")
driver.get(india)

# %%
GDP = driver.find_element(By.XPATH,"//ul[@style = 'list-style-type:none;margin-left:20px;']/li/a").get_attribute('href')
driver.get(GDP)

# %%
# Scrapping Details
ranks=[]
states=[]
GSDP_18_19=[]
GSDP_19_20=[]
share_18_19=[]
GDP_in_billion=[]

# Rank
for rank in driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[1]"):
    ranks.append(rank.text)
# States
for state in driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[2]"):
    states.append(state.text)
# GSDP for 19-20
for gsdp in driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[3]"):
    GSDP_19_20.append(gsdp.text)
# GSDP 18-19
for gsdp in driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[4]"):
    GSDP_18_19.append(gsdp.text)      
# Share    
for share in driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[5]"):
    share_18_19.append(share.text)    
# GDP in $ billion
for gdp in driver.find_elements(By.XPATH,"//table[@id='table_id']/tbody/tr/td[6]"):
    GDP_in_billion.append(gdp.text)

# %%
df=pd.DataFrame({})
df["Rank"]=ranks
df["State"]=states
df["GSDP(19-20)"]=GSDP_19_20
df["GSDP(18-19)"]=GSDP_18_19
df["Share(18-19)"]=share_18_19
df["GDP($ billion)"]=GDP_in_billion
df
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19) Share(18-19)  \
# 0     1                Maharashtra           -   2,632,792       13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208        8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764        8.39%
# 3     4                    Gujarat           -   1,502,899        7.96%
# 4     5                  Karnataka   1,631,977   1,493,127        7.91%
# 5     6                West Bengal   1,253,832   1,089,898        5.77%
# 6     7                  Rajasthan   1,020,989     942,586        4.99%
# 7     8             Andhra Pradesh     972,782     862,957        4.57%
# 8     9                  Telangana     969,604     861,031        4.56%
# 9    10             Madhya Pradesh     906,672     809,592        4.29%
# 10   11                     Kerala           -     781,653        4.14%
# 11   12                      Delhi     856,112     774,870        4.10%
# ...

# %%
driver.close()

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# ASSIGNMENT
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")
driver.maximize_window()

# %%
# Getting the webpage of mentioned url 
driver.get('https://github.com/')

# %%
#Getting explore button and clicking on it
explore = driver.find_elements(By.XPATH,"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details")

# %%
#Selecting trending option
trend_url = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
# making empty lists    
repo_urls=[]
Contributors_count=[]
Language_used=[]
repo_title=[]
repo_desc=[]

# %%
#scraping repositories urls
repos=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]/a')
for i in repos:
    repo_urls.append(i.get_attribute('href'))
time.sleep(2)

# %%
repo_urls
# Out:
# ['https://github.com/charmbracelet/vhs',
#  'https://github.com/bytedance/bitsail',
#  'https://github.com/simeydotme/pokemon-cards-css',
#  'https://github.com/alvaroreis/bolsonaro2turno',
#  'https://github.com/shieldfy/API-Security-Checklist',
#  'https://github.com/vercel/app-playground',
#  'https://github.com/shadcn/taxonomy',
#  'https://github.com/vercel/turbo',
#  'https://github.com/sismo-core/sismo-protocol',
#  'https://github.com/google/googletest',
#  'https://github.com/mastodon/mastodon',
#  'https://github.com/minbrowser/min',
#  'https://github.com/oven-sh/bun',
#  'https://github.com/jynew/jynew',
#  'https://github.com/curl/curl',
#  'https://github.com/JustAnotherArchivist/snscrape',
#  'https://github.com/fzyzcjy/flutter_smooth',
#  'https://github.com/apache/incubator-seatunnel',
#  'https://github.com/hashicorp/terraform',
#  'https://github.com/dotnet/samples',
#  'https://github.com/jetlinks/jetlinks-community',
#  'https://github.com/dotnet/maui',
# ...

# %%
#scraping repositories title
repo_title=[]
try:
    repos=driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']")
    for i in repos:
        repo_title.append(i.text)
except NoSuchElementException:#handling no such element exception
    repo_title.append('No details available')
time.sleep(3)
    
    
for i in repo_urls:
    driver.get(i)
    l=[]
    time.sleep(3)
     #scraping repositories discription
    try:          
        repo_desc.append(driver.find_element(By.XPATH,"/html/body/div[4]/div/main/turbo-frame/div/div/div/div[3]/div[2]/div/div[1]/div/p").text)
    except:
        repo_desc.append('-')
    
    #scraping contributors count
    try:
        count=driver.find_element(By.XPATH,"//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        Contributors_count.append(count.text)
    except NoSuchElementException:#handling no such element exception
        Contributors_count.append('No details available')
    time.sleep(2)
    
     #scraping languages used   
    languages=driver.find_elements(By.XPATH,"//li[@class='d-inline']//a//span[1]")
    if languages:    
        for i in languages:
            l.append(i.text)
    else:
        l.append('No languages used')
    Language_used.append(l)   
    
time.sleep(2)   
#creating dataframe
df=pd.DataFrame({'Title':repo_title,
                'Description':repo_desc,
                'Contributors_count':Contributors_count,
                'Language_used':Language_used})
df
# Out:
#                                        Title  \
# 0                        charmbracelet / vhs
# 1                        bytedance / bitsail
# 2             simeydotme / pokemon-cards-css
# 3               alvaroreis / bolsonaro2turno
# 4          shieldfy / API-Security-Checklist
# 5                    vercel / app-playground
# 6                          shadcn / taxonomy
# 7                             vercel / turbo
# 8                sismo-core / sismo-protocol
# 9                        google / googletest
# 10                       mastodon / mastodon
# 11                          minbrowser / min
# 12                             oven-sh / bun
# 13                             jynew / jynew
# 14                               curl / curl
# 15           JustAnotherArchivist / snscrape
# 16                  fzyzcjy / flutter_smooth
# 17              apache / incubator-seatunnel
# 18                     hashicorp / terraform
# 19                          dotnet / samples
# ...

# %%
driver.close()

# %% [markdown]
# Q 6 ) Scrape the details of top 100 songs on billiboard.com. Url = https://www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")
driver.maximize_window()

# %%
driver.get(" https://www.billboard.com/")

# %%
option_chart=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
option_chart.click()

# %%
view_chart=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
view_chart.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Input In [56], in <cell line: 2>()
#       1 view_chart=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
# ----> 2 view_chart.click()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# ...

# %%
Name = []
Artist = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# %%
#scraping song names
try:
    names=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]//h3')
    for i in names:
        Name.append(i.text)
except NoSuchElementException:       
    Name.append('No details available')
time.sleep(2)    
Name=Name[::4][:100]

# %%
len(Name)
# Out:
# 0

# %%
#scraping artist names
try:
    artist=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]//span')
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException:     
    Artist.append('-')
time.sleep(2)    
Artist=Artist[::7][:100]

# %%
len(Artist)
# Out:
# 0

# %%
#scraping last week rank of the song
try:
    last_rank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]')
    for i in last_rank:
        Last_week_rank.append(i.text)
except NoSuchElementException:      
    Last_week_rank.append('-')
    time.sleep(2)    
Last_week_rank=Last_week_rank[::2][:100]

# %%
len(Last_week_rank)
# Out:
# 0

# %%
#scraping song's peak rank
try:
    peak=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max"]')
    for i in peak:
        Peak_rank.append(i.text)
except NoSuchElementException:       
    Peak_rank.append('-')
time.sleep(2)    
Peak_rank=Peak_rank[1::2][:100]

# %%
len(Peak_rank)
# Out:
# 0

# %%
#scraping number of weeks on board
try:
    weeks=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]')
    for i in weeks:
        Weeks_on_board.append(i.text)
except NoSuchElementException:       #handling no such element exception
    Weeks_on_board.append('-')
time.sleep(2)    
Weeks_on_board=Weeks_on_board[1::2][:100]

# %%
len(Weeks_on_board)
# Out:
# 0

# %%
df=pd.DataFrame({'Song_Name':Name,
                'Artist_Name':Artist,
                'Last_week_rank':Last_week_rank,
                'Peak':Peak_rank,
                'Weeks_on_chart':Weeks_on_board})
df
# Out:
# Empty DataFrame
# Columns: [Song_Name, Artist_Name, Last_week_rank, Peak, Weeks_on_chart]
# Index: []

# %%
driver.close()

# %% [markdown]
# Q 7) Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")
driver.maximize_window()

# %%
# Getting the webpage of mentioned url 
driver.get("https://www.naukri.com/hr-recruiters-consultants")

# %%
#clicking on recruiters link
recruiters=driver.find_element(By.XPATH,"//a[@title='Search Recruiters']")
driver.get(recruiters.get_attribute('href'))
time.sleep(1)

# %%
#accesing search bar
search=driver.find_element(By.XPATH,"//input[@class='sugInp']")
search.send_keys("Data Science")
time.sleep(1)

# %%
#clicking on search button
button=driver.find_element(By.XPATH,"//button[@id='qsbFormBtn']")
button.click()
time.sleep(1)

# %%
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

# %%
#Scraping data of Names
for i in driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


#Scraping data of Designation

for i in driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']"):
    Designation.append(i.text)
    

#Scraping data of company name

for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)

    
#Scraping data of locations

for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]//span"):
    Location.append(i.text)
time.sleep(3)

# %%
print(len(Name),len(Designation),len(Company),len(Location))
# Out:
# 50 50 50 148

# %%
# Creating dataframe 
Naukri=pd.DataFrame({})

Naukri['Name'] = Name
Naukri['Designation'] = Designation
Naukri['Company'] = Company
Naukri['Location'] = Location[:50]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                             Mahesh Babu Channa
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Vaishnavi Kudalkar
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %% [markdown]
# Q 8) Scrape the details of Highest selling novels. Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")
driver.maximize_window()

# %%
# Getting the webpage of mentioned url 
driver.get(" https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/")

# %%
# ceate empty list to store the details
book = []
author = []
volume = []
publisher = []
genre = []

# %%
# Book_name
for i in driver.find_elements(By.XPATH,"//div[@class='embed block']/table/tbody/tr/td[2]"):
    book.append(i.text)
# Author_name
for j in driver.find_elements(By.XPATH,"//div[@class='embed block']/table/tbody/tr/td[3]"):
    author.append(j.text)
# Volumes sold
for k in driver.find_elements(By.XPATH,"//div[@class='embed block']/table/tbody/tr/td[4]"):
    volume.append(k.text)
# Publisher
for l in driver.find_elements(By.XPATH,"//div[@class='embed block']/table/tbody/tr/td[5]"):
    publisher.append(l.text)
# Genre
for m in driver.find_elements(By.XPATH,"//div[@class='embed block']/table/tbody/tr/td[6]"):
    genre.append(m.text)

# %%
# Create Dataframe
df=pd.DataFrame({})
df["Book Name"]=book
df["Author name"]=author
df["Volumes sold"]=volume
df["Publisher"]=publisher
df["Genre"]=genre
df
# Out:
#                                             Book Name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")
driver.maximize_window()

# %%
# Getting the webpage of mentioned url 
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
name = []
year = []
genre = []
run_time = []
ratings = []
votes = []

# %%
# Name
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/h3/a"):
    name.append(i.text)
# Year
for j in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/h3/span[2]"):
    year.append(j.text)
# Genre
for k in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/p/span[5]"):
    genre.append(k.text)
# Run Time
for l in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/p/span[3]"):
    run_time.append(l.text)
# Votes
for n in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/div[1]/div/span[2]"):
    ratings.append(n.text)
# Ratings
for m in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/p[4]/span[2]"):
    votes.append(m.text)

# %%
# Creating Dataframe
df = pd.DataFrame({})
df["Name"] = name
df["Year span"] = year
df["Genre"] = genre
df["Run time"] = run_time
df["Ratings"] = ratings
df["Votes"] = votes
df
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  2,059,399
# ...

# %%
driver.close()

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Chrome driver\Chromedriver.exe")
driver.maximize_window()

# %%
# Getting the webpage of mentioned url 
driver.get("https://archive.ics.uci.edu/")

# %%
# fetching view all dataset button from the webpage
viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(3)

# %%
# fetching page urls of all datasets
view_list = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")
list_url = view_list.get_attribute("href")
driver.get(list_url)
time.sleep(3)

# %%
# fetching urls for each dataset
dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")

urls = []
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
# creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    
    
    # scraping  Dataset name
    try:
        dataset_name = driver.find_element_by_xpath("//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    time.sleep(3)
    
    
    
    # scraping data type
    try:
        data_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(3)
    
    
    # scraping Task
    try:
        task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(3)
    
    
    
    # scraping Attribute type
    try:
        attribute_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    time.sleep(3)
    
    
    
    # scraping No of Instances
    try:
        instances = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    time.sleep(3)
    
    
    
    # scraping No of Arrtibutes
    try:
        attribute = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    time.sleep(3)
    
    
    # scraping Year
    try:
        year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(3)

# %%
#DATA FRAMEING
UCI=pd.DataFrame({})
UCI['Data Name'] = Data_name
UCI['Data Type'] = Data_type
UCI['Task'] = Task
UCI['Attribute type'] = Attr_type
UCI['No of instance'] = Instances
UCI['No of attributes'] = n_attributes
UCI['Year'] = Year
UCI
